# %%
#!pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.10/dist-packages (from newsapi-python) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2023.11.17)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7

# %%
import pandas as pd
from newsapi import NewsApiClient
from IPython.display import JSON
from config import NEW_API

# %%
newsapi=NewsApiClient(api_key=NEW_API)
top_headlines=newsapi.get_top_headlines(q="bitcoin",sources="bbc-news,the-verge",
                                        language="en")

# %%
sources=newsapi.get_sources()

# %%
sources["sources"]

# %%
data=[]
for source in sources["sources"]:
  id=source["id"]
  name=source["name"]
  description=source["description"]
  url=source["url"]
  kategori=source["category"]
  language=source["language"]
  country=source["country"]

  data.append({"name":name,"id":id,"description":description,"url":url,"kategori":kategori,"language":language,"country":country})
df=pd.DataFrame(data)
df
# Out:
#                    name                  id  \
# 0              ABC News            abc-news
# 1         ABC News (AU)         abc-news-au
# 2           Aftenposten         aftenposten
# 3    Al Jazeera English  al-jazeera-english
# 4               ANSA.it                ansa
# ..                  ...                 ...
# 123               Wired               wired
# 124            Wired.de            wired-de
# 125   Wirtschafts Woche   wirtschafts-woche
# 126          Xinhua Net          xinhua-net
# 127                Ynet                ynet
#
#                                            description  \
# 0    Your trusted source for breaking news, analysi...
# 1    Australia's most trusted source of local, nati...
# 2    Norges ledende nettavis med alltid oppdaterte ...
# 3    News, analysis from the Middle East and worldw...
# 4    Agenzia ANSA: ultime notizie, foto, video e ap...
# ..                                                 ...
# 123  Wired is a monthly American magazine, publishe...
# 124  Wired reports on how emerging technologies aff...
# 125  Das Online-Portal des führenden Wirtschaftsmag...
# 126  中国主要重点新闻网站,依托新华社遍布全球的采编网络,记者遍布世界100多个国家和地区,地方频...
# 127  ynet דף הבית: אתר החדשות המוביל בישראל מבית יד...
#
#                             url    kategori language country
# 0        https://abcnews.go.com     general       en      us
# 1    http://www.abc.net.au/news     general       en      au
# 2    https://www.aftenposten.no     general       no      no
# 3      http://www.aljazeera.com     general       en      us
# 4            http://www.ansa.it     general       it      it
# ..                          ...         ...      ...     ...
# 123       https://www.wired.com  technology       en      us
# 124        https://www.wired.de  technology       de      de
# 125          http://www.wiwo.de    business       de      de
# 126       http://xinhuanet.com/     general       zh      zh
# 127       http://www.ynet.co.il     general       he      is
#
# [128 rows x 7 columns]

# %%
df.head()
# Out:
#                  name                  id  \
# 0            ABC News            abc-news
# 1       ABC News (AU)         abc-news-au
# 2         Aftenposten         aftenposten
# 3  Al Jazeera English  al-jazeera-english
# 4             ANSA.it                ansa
#
#                                          description  \
# 0  Your trusted source for breaking news, analysi...
# 1  Australia's most trusted source of local, nati...
# 2  Norges ledende nettavis med alltid oppdaterte ...
# 3  News, analysis from the Middle East and worldw...
# 4  Agenzia ANSA: ultime notizie, foto, video e ap...
#
#                           url kategori language country
# 0      https://abcnews.go.com  general       en      us
# 1  http://www.abc.net.au/news  general       en      au
# 2  https://www.aftenposten.no  general       no      no
# 3    http://www.aljazeera.com  general       en      us
# 4          http://www.ansa.it  general       it      it

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         128 non-null    object
#  1   id           128 non-null    object
#  2   description  128 non-null    object
#  3   url          128 non-null    object
#  4   kategori     128 non-null    object
#  5   language     128 non-null    object
#  6   country      128 non-null    object
# dtypes: object(7)
# memory usage: 7.1+ KB

# %%
#crearting workflow
def json_to_dataframe(api_key):
  newsapi=NewsApiClient(api_key=api_key)
  top_headlines=newsapi.get_top_headlines(q="bitcoin",sources="bbc-news,the-verge",language="en")
  sources=newsapi.get_sources()
  data=[]
  for source in sources["sources"]:
    id=source["id"]
    name=source["name"]
    category=source["category"]
    description=source["description"]
    country=source["country"]
    language=source["language"]
    url=source["url"]
    data.append({"id":id,"name":name,"category":category,"description":description,"country":country,"language":language,"url":url})
  df=pd.DataFrame(data)
  return df

# %%
json_to_dataframe(NEW_API)
# Out:
#                      id                name    category  \
# 0              abc-news            ABC News     general
# 1           abc-news-au       ABC News (AU)     general
# 2           aftenposten         Aftenposten     general
# 3    al-jazeera-english  Al Jazeera English     general
# 4                  ansa             ANSA.it     general
# ..                  ...                 ...         ...
# 123               wired               Wired  technology
# 124            wired-de            Wired.de  technology
# 125   wirtschafts-woche   Wirtschafts Woche    business
# 126          xinhua-net          Xinhua Net     general
# 127                ynet                Ynet     general
#
#                                            description country language  \
# 0    Your trusted source for breaking news, analysi...      us       en
# 1    Australia's most trusted source of local, nati...      au       en
# 2    Norges ledende nettavis med alltid oppdaterte ...      no       no
# 3    News, analysis from the Middle East and worldw...      us       en
# 4    Agenzia ANSA: ultime notizie, foto, video e ap...      it       it
# ..                                                 ...     ...      ...
# 123  Wired is a monthly American magazine, publishe...      us       en
# 124  Wired reports on how emerging technologies aff...      de       de
# 125  Das Online-Portal des führenden Wirtschaftsmag...      de       de
# 126  中国主要重点新闻网站,依托新华社遍布全球的采编网络,记者遍布世界100多个国家和地区,地方频...      zh       zh
# 127  ynet דף הבית: אתר החדשות המוביל בישראל מבית יד...      is       he
#
#                             url
# 0        https://abcnews.go.com
# 1    http://www.abc.net.au/news
# 2    https://www.aftenposten.no
# 3      http://www.aljazeera.com
# 4            http://www.ansa.it
# ..                          ...
# 123       https://www.wired.com
# 124        https://www.wired.de
# 125          http://www.wiwo.de
# 126       http://xinhuanet.com/
# 127       http://www.ynet.co.il
#
# [128 rows x 7 columns]
